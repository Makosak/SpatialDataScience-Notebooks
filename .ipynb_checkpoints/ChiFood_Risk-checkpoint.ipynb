# %% [markdown]
# # SUR Model Measuring Great Recession Impact on FA
#
# See SUR documentation here: http://pysal.readthedocs.io/en/latest/library/spreg/sur.html

# %% [markdown]
# ### Open required libraries

# %%
import pysal

# %%
import sys
sys.path.append('/Users/Masia/Code/spreg')

# %%
from sur import SUR
from sur_utils import sur_dictxy,sur_dict2mat,sur_mat2dict,sur_corr,sur_crossprod,sur_est,sur_resids,sur_predict,check_k

# %%
import numpy as np
import numpy.linalg as la
import scipy.stats as stats
import summary_output as SUMMARY
from diagnostics_sur import sur_setp,sur_lrtest,sur_lmtest,surLMe,surLMlag,sur_chow

# %% [markdown]
# ### Open DBF file for Analysis

# %%
db = pysal.open("/Users/Masia/Desktop/FinalChiCluster.dbf")

# %% [markdown]
# ### Build Spatial Weight

# %%
## Queen-Contiguity Spatial Weight generated
w = pysal.queen_from_shapefile("/Users/Masia/Desktop/FinalChiCluster.shp")
w.transform='r'

# %% [markdown]
# ### Generate List of Variables

# %%
## Log (Network Distance Miles to Supermarkets / Population of Tract)
y_var = ['FA07RT','FA11RT']

## Covariates: Log(PerCap Income), Dummy Variables for Race, Excess Risk for Foreclosure as Treatment)
x_var=[['LINC10','HispMaj10','BlackMaj10','WHITEMAJ10','RISK0'],
       ['LINC12','HISPMAJ12','BLKMAJ12','WHITEMAJ12','Risk1']]

# %% [markdown]
# ### Build Variable Dictionaries

# %%
#bigy,bigX,bigyvars,bigXvars = pysal.spreg.sur_utils.sur_dictxy(db,y_var,x_var)
bigy,bigX,bigyvars,bigXvars = sur_dictxy(db,y_var,x_var)

# %% [markdown]
# ### Run SUR Regressions

# %%
#reg = pysal.spreg.sur.SUR(bigy,bigX,w=w,name_bigy=bigyvars,name_bigX=bigXvars,
#                          spat_diag=True,name_ds="nat",name_w=w)

reg = pysal.spreg.sur.SUR(bigy,bigX,w=w,name_bigy=bigyvars,name_bigX=bigXvars,
                          spat_diag=True,name_ds="nat",name_w=w)

print(reg.summary)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-25-af2a77892fcc> in <module>()
#       3
#       4 reg = pysal.spreg.sur.SUR(bigy,bigX,w=w,name_bigy=bigyvars,name_bigX=bigXvars,
# ----> 5                           spat_diag=True,name_ds="nat",name_w=w)
#       6
#       7 print(reg.summary)
#
# /Users/Masia/anaconda/lib/python2.7/site-packages/pysal/spreg/sur.pyc in __init__(self, bigy, bigX, w, nonspat_diag, spat_diag, vm, iter, maxiter, epsilon, verbose, name_bigy, name_bigX, name_ds, name_w)
#     319         # init moved here before name check
#     320         BaseSUR.__init__(self,bigy=bigy,bigX=bigX,iter=iter,\
# --> 321             maxiter=maxiter,epsilon=epsilon,verbose=verbose)
#     322
#     323         self.name_ds = USER.set_name_ds(name_ds)
#
# /Users/Masia/anaconda/lib/python2.7/site-packages/pysal/spreg/sur.pyc in __init__(self, bigy, bigX, iter, maxiter, epsilon, verbose)
#      81         self.bigXX,self.bigXy = sur_crossprod(self.bigX,self.bigy)
#      82         # OLS regression by equation, sets up initial residuals
# ---> 83         self.sur_ols() # creates self.bOLS and self.olsE
#      84         # SUR estimation using OLS residuals - two step estimation
#      85         self.bSUR,self.varb,self.sig = sur_est(self.bigXX,self.bigXy,self.olsE,self.bigK)
#
# /Users/Masia/anaconda/lib/python2.7/site-packages/pysal/spreg/sur.pyc in sur_ols(self)
#     133         self.bOLS = {}
#     134         for r in range(self.n_eq):
# --> 135             self.bOLS[r] = np.dot(la.inv(self.bigXX[(r,r)]),self.bigXy[(r,r)])
#     136         self.olsE = sur_resids(self.bigy,self.bigX,self.bOLS)
#     137
#
# /Users/Masia/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     524     signature = 'D->D' if isComplexType(t) else 'd->d'
#     525     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 526     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     527     return wrap(ainv.astype(result_t, copy=False))
#     528
#
# /Users/Masia/anaconda/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# ## Y Observed

# %%
#dictionary with Y values
#reg.bigy

# %%
# Stack columns of the dictionary
d = reg.bigy
y_obs = np.concatenate(list(d.values()))

# %%
len(y_obs)
# Out:
# 2373

# %%
type(y_obs)
# Out:
# numpy.ndarray

# %%
y_obs.shape
# Out:
# (2373, 1)

# %%
y_obs
# Out:
# array([[ 0.4336],
#        [ 0.3749],
#        [ 0.2583],
#        ...,
#        [ 0.4936],
#        [ 0.6822],
#        [ 1.4685]])

# %% [markdown]
# ## Y Predicted

# %%
# Generate matrix for predicted Y
bSUR,varb,sig = sur_est(reg.bigXX,reg.bigXy,reg.olsE,reg.bigK)
bigYP = sur_predict(bigy,bigX,bSUR)

# %%
type(bigYP)
# Out:
# numpy.ndarray

# %%
y_exp = np.hstack(bigYP)

# %%
len(y_exp)
# Out:
# 2373

# %%
type(y_exp)
# Out:
# numpy.ndarray

# %%
y_exp.shape
# Out:
# (2373,)

# %%
y_exp.resize((2373, 1))

# %%
y_exp.shape
# Out:
# (2373, 1)

# %%
y_exp
# Out:
# array([[ 0.93121489],
#        [ 0.90249535],
#        [ 0.78031948],
#        ...,
#        [ 1.14449994],
#        [ 1.13007412],
#        [ 1.13106587]])

# %% [markdown]
# ## Plot Observed vs Predicted Y

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#custom 
fig = plt.figure(figsize=(9,9))
plt.scatter(y_obs,y_exp, c='k', s=40, alpha=.6)
plt.xlabel("Observed Y", fontsize=20)
plt.ylabel("Predicted Y", fontsize=20)

plt.show()

# %% [markdown]
# ## Calculate Crude R Squared

# %%
cor = stats.pearsonr(y_obs,y_exp)

# %%
cor
# Out:
# (array([-0.03141221]), array([ 0.12607412]))

# %%
Rsquare = 0.12607412**2

# %%
Rsquare
# Out:
# 0.015894683733774402
